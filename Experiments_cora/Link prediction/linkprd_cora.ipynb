# %%
# %pip install torch torch_geometric
# Out:
# Collecting torch_geometric
#   Using cached torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# Collecting aiohttp (from torch_geometric)
#   Using cached aiohttp-3.12.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (2023.9.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (1.24.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from torch_geometric) (4.66.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->torch_geometric)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->torch_geometric)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->torch_geometric) (23.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->torch_geometric)
#   Using cached frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->torch_geometric)
#   Using cached multidict-6.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->torch_geometric)
#   Using cached propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->torch_geometric)
#   Using cached yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch_geometric) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->torch_geometric) (2023.7.22)
# Using cached torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
# Using cached aiohttp-3.12.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
# Using cached multidict-6.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
# Using cached propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Using cached yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
# Installing collected packages: propcache, multidict, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp, torch_geometric
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.13 aiosignal-1.3.2 frozenlist-1.7.0 multidict-6.5.0 propcache-0.3.2 torch_geometric-2.6.1 yarl-1.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
"""LINK PREDICTION"""    
import torch
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import JumpingKnowledge, GCNConv, MixHopConv
import torch_geometric.transforms as T
import time
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)


class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_layers=6, dropout=0.5):
        super(GCN, self).__init__()
        self.dropout = dropout
        self.convs = torch.nn.ModuleList()
        self.convs.append(GCNConv(in_channels, hidden_channels))
        for _ in range(num_layers - 1):
            self.convs.append(GCNConv(hidden_channels, hidden_channels))

    def forward(self, x, edge_index):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            if i < len(self.convs) - 1:
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=self.training)
        return x

class JKNetMax(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels=16, num_layers=6, dropout=0.5):
        super(JKNetMax, self).__init__()
        self.dropout = dropout
        self.convs = torch.nn.ModuleList()
        self.convs.append(GCNConv(in_channels, hidden_channels))
        for _ in range(num_layers - 1):
            self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.jump = JumpingKnowledge(mode='max', channels=hidden_channels, num_layers=num_layers)

    def forward(self, x, edge_index):
        xs = []
        for conv in self.convs:
            x = conv(x, edge_index)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
            xs.append(x)
        return self.jump(xs)

class MixHopEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels=32, dropout=0.5, powers=[0, 1, 2]):
        super(MixHopEncoder, self).__init__()
        self.conv1 = MixHopConv(in_channels, hidden_channels, powers=powers)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        return x


class AlternatingGCNMixHopJKNet(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, num_layers=2, hop_hidden_channels=32, mode='max', dropout=0.4, mixhop_powers=[0,1,2]):
        super(AlternatingGCNMixHopJKNet, self).__init__()
        self.dropout = dropout
        self.num_layers = num_layers
        self.convs = torch.nn.ModuleList()
        self.lins = torch.nn.ModuleList()
        for i in range(num_layers):
            if i % 2 == 0:
                in_c = in_channels if i == 0 else hidden_channels
                self.convs.append(GCNConv(in_c, hidden_channels))
                self.lins.append(torch.nn.Identity())
            else:
                self.convs.append(MixHopConv(hidden_channels, hop_hidden_channels, powers=mixhop_powers))
                self.lins.append(torch.nn.Linear(hop_hidden_channels * len(mixhop_powers), hidden_channels))
        self.jump = JumpingKnowledge(mode=mode, channels=hidden_channels, num_layers=num_layers)

    def forward(self, x, edge_index):
        xs = []
        for i in range(self.num_layers):
            if i % 2 == 0:
                x = self.convs[i](x, edge_index)
                x = F.relu(x)
            else:
                x = self.convs[i](x, edge_index)
                x = self.lins[i](x)
                x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
            xs.append(x)
        return self.jump(xs)

class LinkPredictor(torch.nn.Module):
    def __init__(self, encoder, decoder_in_channels, decoder_hidden_channels=128):
        super().__init__()
        self.encoder = encoder
        self.decoder = torch.nn.Sequential(
            torch.nn.Linear(decoder_in_channels, decoder_hidden_channels),
            torch.nn.ReLU(),
            torch.nn.Dropout(p=0.5),
            torch.nn.Linear(decoder_hidden_channels, 1)
        )

    def forward(self, x, edge_index, edge_label_index):
        z = self.encoder(x, edge_index)
        
        src_emb = z[edge_label_index[0]]
        dst_emb = z[edge_label_index[1]]
        emb_cat = torch.cat([src_emb, dst_emb], dim=-1)
        
        return self.decoder(emb_cat).squeeze()

def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index, data.edge_label_index)
    loss = F.binary_cross_entropy_with_logits(out, data.edge_label)
    loss.backward()
    optimizer.step()
    return float(loss)

@torch.no_grad()
def test(model, train_data, data_to_test):
    model.eval()
    with torch.no_grad():
        out = model(train_data.x, train_data.edge_index, data_to_test.edge_label_index)
    out = out.sigmoid()
    return roc_auc_score(data_to_test.edge_label.cpu().numpy(), out.cpu().numpy())

def plot_metrics(history, model_name, seed):
    epochs = range(1, len(history['loss']) + 1)
    plt.figure(figsize=(15, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history['loss'], 'y-', label='Training Loss')
    plt.title(f'Loss for {model_name}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history['val_auc'], 'r-', label='Validation AUC')
    plt.plot(epochs, history['test_auc'], 'g-', label='Test AUC')
    plt.title(f'AUC for {model_name}')
    plt.xlabel('Epochs')
    plt.ylabel('AUC')
    plt.grid(True)
    plt.legend()
    plt.suptitle(f'Link Prediction Metrics for {model_name} (Seed: {seed})')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

def run(encoder_class_lambda, model_name, seed, embedding_dim):
    set_seed(seed)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    dataset = Planetoid(root='./Cora', name='Cora', transform=T.NormalizeFeatures())
    data = dataset[0]
    
    transform = T.RandomLinkSplit(num_val=0.05, num_test=0.1, is_undirected=True, add_negative_train_samples=True)
    train_data, val_data, test_data = transform(data)
    
    encoder = encoder_class_lambda(dataset.num_features).to(device)
    
    model = LinkPredictor(encoder, 2 * embedding_dim).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.0005, weight_decay=5e-4)

    best_val_auc, final_test_auc, patience = 0, 0, 10000
    wait = 0
    history = {'loss': [], 'val_auc': [], 'test_auc': []}

    for epoch in range(1, 10000):
        loss = train(model, optimizer, train_data.to(device))
        val_auc = test(model, train_data.to(device), val_data.to(device))
        test_auc = test(model, train_data.to(device), test_data.to(device))
        
        history['loss'].append(loss)
        history['val_auc'].append(val_auc)
        history['test_auc'].append(test_auc)

        if val_auc > best_val_auc:
            best_val_auc = val_auc
            final_test_auc = test_auc
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print(f"{model_name} Early stop at epoch {epoch}")
                break
        
        if epoch % 100 == 0:
            print(f"{model_name} Epoch {epoch:03d}, Loss {loss:.4f}, Val AUC {val_auc:.4f}, Test AUC {test_auc:.4f}")

    print(f"{model_name} Seed {seed} → Best Val AUC {best_val_auc:.4f}, Test @BestVal = {final_test_auc:.4f}\n")
    plot_metrics(history, model_name, seed)
    return final_test_auc

if __name__ == '__main__':
    seeds = [123]
    
    dataset = Planetoid(root='./Cora', name='Cora', transform=T.NormalizeFeatures())
    in_c = dataset.num_features

    models = [
        ('GCN', GCN(in_c, hidden_channels=32, num_layers=2, dropout=0.5)),
        ('JKNet', JKNetMax(in_c, hidden_channels=32, num_layers=6, dropout=0.5)),
        ('MixHop', MixHopEncoder(in_c, hidden_channels=32, dropout=0.5)),
        ('AltGCNMixJKN', AlternatingGCNMixHopJKNet(in_c, hidden_channels=32, num_layers=3, hop_hidden_channels=32, mode='max', dropout=0.4))
    ]
    
    for name, model in models:
        num_params = sum(p.numel() for p in model.parameters())
        print(f'{name}: {num_params:,} parameters')
    
    telescopic_results = []
    
    print("===== Regular 2-layer GCN =====")
    gcn_results = [run(lambda in_c: GCN(in_c, hidden_channels=32, num_layers=2, dropout=0.5), "GCN", s, embedding_dim=32) for s in seeds]
    
    print("===== JKNet Max Pool =====")
    jknet_results = [run(lambda in_c: JKNetMax(in_c, hidden_channels=32, num_layers=6, dropout=0.5), "JKNetMax", s, embedding_dim=32) for s in seeds]
    
    print("===== MixHop =====")
    mixhop_results = [run(lambda in_c: MixHopEncoder(in_c, hidden_channels=32, dropout=0.5), "MixHop", s, embedding_dim=96) for s in seeds]
    
    print("===== alternating MixHop JKNet =====")
    alternating_results = [run(lambda in_c: AlternatingGCNMixHopJKNet(in_c, hidden_channels=32, num_layers=3, hop_hidden_channels=32, mode='max', dropout=0.4), "AlternatingGCNMixHopJKNet", s, embedding_dim=32) for s in seeds]

    print(f"GCN Mean Test AUC = {sum(gcn_results)/len(gcn_results):.4f} ± {torch.std(torch.tensor(gcn_results), unbiased=False):.4f}")
    print(f"JKNetMax Mean Test AUC = {sum(jknet_results)/len(jknet_results):.4f} ± {torch.std(torch.tensor(jknet_results), unbiased=False):.4f}")
    print(f"MixHop Mean Test AUC = {sum(mixhop_results)/len(mixhop_results):.4f} ± {torch.std(torch.tensor(mixhop_results), unbiased=False):.4f}")
    if telescopic_results:
        print(f"TelescopicMixHopJKNet Mean Test AUC = {sum(telescopic_results)/len(telescopic_results):.4f} ± {torch.std(torch.tensor(telescopic_results), unbiased=False):.4f}")
    print(f"AlternatingMixHopJKNet Mean Test AUC = {sum(alternating_results)/len(alternating_results):.4f} ± {torch.std(torch.tensor(alternating_results), unbiased=False):.4f}")
# Out:
# GCN: 51,168 parameters
# JKNet: 51,168 parameters
# MixHop: 137,664 parameters
# AltGCNMixJKN: 52,160 parameters
# ===== Regular 2-layer GCN =====
# GCN Epoch 100, Loss 0.6062, Val AUC 0.6679, Test AUC 0.6903
# GCN Epoch 200, Loss 0.5606, Val AUC 0.6638, Test AUC 0.6954
# GCN Epoch 300, Loss 0.5521, Val AUC 0.6601, Test AUC 0.6947
# GCN Epoch 400, Loss 0.5512, Val AUC 0.6546, Test AUC 0.6911
# GCN Epoch 500, Loss 0.5473, Val AUC 0.6536, Test AUC 0.6902
# GCN Epoch 600, Loss 0.5448, Val AUC 0.6489, Test AUC 0.6894
# GCN Epoch 700, Loss 0.5378, Val AUC 0.6480, Test AUC 0.6865
# GCN Epoch 800, Loss 0.5398, Val AUC 0.6445, Test AUC 0.6878
# GCN Epoch 900, Loss 0.5363, Val AUC 0.6437, Test AUC 0.6847
# GCN Epoch 1000, Loss 0.5376, Val AUC 0.6426, Test AUC 0.6860
# GCN Epoch 1100, Loss 0.5355, Val AUC 0.6412, Test AUC 0.6838
# GCN Epoch 1200, Loss 0.5340, Val AUC 0.6411, Test AUC 0.6814
# GCN Epoch 1300, Loss 0.5319, Val AUC 0.6388, Test AUC 0.6820
# GCN Epoch 1400, Loss 0.5296, Val AUC 0.6387, Test AUC 0.6820
# GCN Epoch 1500, Loss 0.5288, Val AUC 0.6366, Test AUC 0.6811
# GCN Epoch 1600, Loss 0.5298, Val AUC 0.6356, Test AUC 0.6817
# GCN Epoch 1700, Loss 0.5266, Val AUC 0.6347, Test AUC 0.6827
# GCN Epoch 1800, Loss 0.5225, Val AUC 0.6355, Test AUC 0.6817
# GCN Epoch 1900, Loss 0.5220, Val AUC 0.6373, Test AUC 0.6804
# GCN Epoch 2000, Loss 0.5156, Val AUC 0.6380, Test AUC 0.6815
# GCN Epoch 2100, Loss 0.5125, Val AUC 0.6402, Test AUC 0.6818
# GCN Epoch 2200, Loss 0.4999, Val AUC 0.6479, Test AUC 0.6876
# GCN Epoch 2300, Loss 0.4700, Val AUC 0.6712, Test AUC 0.7030
# GCN Epoch 2400, Loss 0.4180, Val AUC 0.7115, Test AUC 0.7375
# GCN Epoch 2500, Loss 0.3410, Val AUC 0.7630, Test AUC 0.7849
# GCN Epoch 2600, Loss 0.3053, Val AUC 0.7757, Test AUC 0.7931
# GCN Epoch 2700, Loss 0.2797, Val AUC 0.7801, Test AUC 0.7939
# GCN Epoch 2800, Loss 0.2657, Val AUC 0.7831, Test AUC 0.7938
# GCN Epoch 2900, Loss 0.2555, Val AUC 0.7851, Test AUC 0.7953
# GCN Epoch 3000, Loss 0.2465, Val AUC 0.7884, Test AUC 0.7946
# GCN Epoch 3100, Loss 0.2444, Val AUC 0.7883, Test AUC 0.7955
# GCN Epoch 3200, Loss 0.2343, Val AUC 0.7876, Test AUC 0.7954
# GCN Epoch 3300, Loss 0.2341, Val AUC 0.7867, Test AUC 0.7971
# GCN Epoch 3400, Loss 0.2277, Val AUC 0.7848, Test AUC 0.7966
# GCN Epoch 3500, Loss 0.2215, Val AUC 0.7844, Test AUC 0.7958
# GCN Epoch 3600, Loss 0.2254, Val AUC 0.7840, Test AUC 0.7959
# GCN Epoch 3700, Loss 0.2176, Val AUC 0.7849, Test AUC 0.7956
# GCN Epoch 3800, Loss 0.2172, Val AUC 0.7850, Test AUC 0.7978
# GCN Epoch 3900, Loss 0.2187, Val AUC 0.7831, Test AUC 0.7944
# GCN Epoch 4000, Loss 0.2120, Val AUC 0.7826, Test AUC 0.7961
# GCN Epoch 4100, Loss 0.2160, Val AUC 0.7810, Test AUC 0.7960
# GCN Epoch 4200, Loss 0.2078, Val AUC 0.7814, Test AUC 0.7943
# GCN Epoch 4300, Loss 0.2158, Val AUC 0.7816, Test AUC 0.7957
# GCN Epoch 4400, Loss 0.2119, Val AUC 0.7801, Test AUC 0.7941
# GCN Epoch 4500, Loss 0.2102, Val AUC 0.7800, Test AUC 0.7951
# GCN Epoch 4600, Loss 0.2072, Val AUC 0.7790, Test AUC 0.7949
# GCN Epoch 4700, Loss 0.2089, Val AUC 0.7789, Test AUC 0.7943
# GCN Epoch 4800, Loss 0.2090, Val AUC 0.7780, Test AUC 0.7946
# GCN Epoch 4900, Loss 0.2053, Val AUC 0.7786, Test AUC 0.7945
# GCN Epoch 5000, Loss 0.2094, Val AUC 0.7799, Test AUC 0.7949
# GCN Epoch 5100, Loss 0.2054, Val AUC 0.7804, Test AUC 0.7932
# GCN Epoch 5200, Loss 0.2044, Val AUC 0.7783, Test AUC 0.7945
# GCN Epoch 5300, Loss 0.2091, Val AUC 0.7776, Test AUC 0.7939
# GCN Epoch 5400, Loss 0.2057, Val AUC 0.7775, Test AUC 0.7950
# GCN Epoch 5500, Loss 0.1994, Val AUC 0.7734, Test AUC 0.7947
# GCN Epoch 5600, Loss 0.2051, Val AUC 0.7755, Test AUC 0.7960
# GCN Epoch 5700, Loss 0.2073, Val AUC 0.7754, Test AUC 0.7936
# GCN Epoch 5800, Loss 0.2041, Val AUC 0.7741, Test AUC 0.7961
# GCN Epoch 5900, Loss 0.1997, Val AUC 0.7746, Test AUC 0.7956
# GCN Epoch 6000, Loss 0.1966, Val AUC 0.7743, Test AUC 0.7965
# GCN Epoch 6100, Loss 0.2032, Val AUC 0.7733, Test AUC 0.7971
# GCN Epoch 6200, Loss 0.1984, Val AUC 0.7741, Test AUC 0.7957
# GCN Epoch 6300, Loss 0.1971, Val AUC 0.7761, Test AUC 0.7955
# GCN Epoch 6400, Loss 0.1973, Val AUC 0.7757, Test AUC 0.7977
# GCN Epoch 6500, Loss 0.2028, Val AUC 0.7746, Test AUC 0.7971
# GCN Epoch 6600, Loss 0.1946, Val AUC 0.7745, Test AUC 0.7964
# GCN Epoch 6700, Loss 0.2001, Val AUC 0.7754, Test AUC 0.7949
# GCN Epoch 6800, Loss 0.1992, Val AUC 0.7752, Test AUC 0.7950
# GCN Epoch 6900, Loss 0.2004, Val AUC 0.7738, Test AUC 0.7965
# GCN Epoch 7000, Loss 0.1962, Val AUC 0.7734, Test AUC 0.7966
# GCN Epoch 7100, Loss 0.2004, Val AUC 0.7758, Test AUC 0.7964
# GCN Epoch 7200, Loss 0.1982, Val AUC 0.7742, Test AUC 0.7960
# GCN Epoch 7300, Loss 0.1953, Val AUC 0.7743, Test AUC 0.7949
# GCN Epoch 7400, Loss 0.1968, Val AUC 0.7755, Test AUC 0.7946
# GCN Epoch 7500, Loss 0.1957, Val AUC 0.7736, Test AUC 0.7937
# GCN Epoch 7600, Loss 0.1919, Val AUC 0.7758, Test AUC 0.7955
# GCN Epoch 7700, Loss 0.1966, Val AUC 0.7725, Test AUC 0.7939
# GCN Epoch 7800, Loss 0.1949, Val AUC 0.7717, Test AUC 0.7954
# GCN Epoch 7900, Loss 0.1988, Val AUC 0.7722, Test AUC 0.7945
# GCN Epoch 8000, Loss 0.1982, Val AUC 0.7731, Test AUC 0.7947
# GCN Epoch 8100, Loss 0.1978, Val AUC 0.7758, Test AUC 0.7949
# GCN Epoch 8200, Loss 0.1934, Val AUC 0.7748, Test AUC 0.7953
# GCN Epoch 8300, Loss 0.1945, Val AUC 0.7721, Test AUC 0.7949
# GCN Epoch 8400, Loss 0.1931, Val AUC 0.7722, Test AUC 0.7937
# GCN Epoch 8500, Loss 0.1917, Val AUC 0.7726, Test AUC 0.7947
# GCN Epoch 8600, Loss 0.1952, Val AUC 0.7743, Test AUC 0.7957
# GCN Epoch 8700, Loss 0.2006, Val AUC 0.7743, Test AUC 0.7944
# GCN Epoch 8800, Loss 0.1962, Val AUC 0.7719, Test AUC 0.7938
# GCN Epoch 8900, Loss 0.1928, Val AUC 0.7715, Test AUC 0.7948
# GCN Epoch 9000, Loss 0.1949, Val AUC 0.7747, Test AUC 0.7958
# GCN Epoch 9100, Loss 0.1950, Val AUC 0.7725, Test AUC 0.7932
# GCN Epoch 9200, Loss 0.1950, Val AUC 0.7740, Test AUC 0.7942
# GCN Epoch 9300, Loss 0.1952, Val AUC 0.7742, Test AUC 0.7938
# GCN Epoch 9400, Loss 0.1938, Val AUC 0.7724, Test AUC 0.7936
# GCN Epoch 9500, Loss 0.2029, Val AUC 0.7738, Test AUC 0.7927
# GCN Epoch 9600, Loss 0.1895, Val AUC 0.7746, Test AUC 0.7942
# GCN Epoch 9700, Loss 0.1882, Val AUC 0.7736, Test AUC 0.7936
# GCN Epoch 9800, Loss 0.1930, Val AUC 0.7733, Test AUC 0.7929
# GCN Epoch 9900, Loss 0.1921, Val AUC 0.7734, Test AUC 0.7929
# GCN Seed 123 → Best Val AUC 0.7887, Test @BestVal = 0.7944
# ===== JKNet Max Pool =====
# JKNetMax Epoch 100, Loss 0.6252, Val AUC 0.6723, Test AUC 0.6965
# JKNetMax Epoch 200, Loss 0.5779, Val AUC 0.6590, Test AUC 0.7093
# JKNetMax Epoch 300, Loss 0.5575, Val AUC 0.6513, Test AUC 0.7073
# JKNetMax Epoch 400, Loss 0.5456, Val AUC 0.6509, Test AUC 0.7022
# JKNetMax Epoch 500, Loss 0.5233, Val AUC 0.6738, Test AUC 0.7099
# JKNetMax Epoch 600, Loss 0.4233, Val AUC 0.7691, Test AUC 0.7813
# JKNetMax Epoch 700, Loss 0.3568, Val AUC 0.8029, Test AUC 0.7965
# JKNetMax Epoch 800, Loss 0.3252, Val AUC 0.8091, Test AUC 0.8010
# JKNetMax Epoch 900, Loss 0.3019, Val AUC 0.8104, Test AUC 0.7996
# JKNetMax Epoch 1000, Loss 0.2893, Val AUC 0.8073, Test AUC 0.7963
# JKNetMax Epoch 1100, Loss 0.2846, Val AUC 0.7985, Test AUC 0.7957
# JKNetMax Epoch 1200, Loss 0.2758, Val AUC 0.7960, Test AUC 0.7930
# JKNetMax Epoch 1300, Loss 0.2591, Val AUC 0.7930, Test AUC 0.7946
# JKNetMax Epoch 1400, Loss 0.2619, Val AUC 0.7929, Test AUC 0.7976
# JKNetMax Epoch 1500, Loss 0.2530, Val AUC 0.7915, Test AUC 0.7996
# JKNetMax Epoch 1600, Loss 0.2510, Val AUC 0.7939, Test AUC 0.8001
# JKNetMax Epoch 1700, Loss 0.2453, Val AUC 0.7888, Test AUC 0.7943
# JKNetMax Epoch 1800, Loss 0.2347, Val AUC 0.7930, Test AUC 0.8012
# JKNetMax Epoch 1900, Loss 0.2332, Val AUC 0.7904, Test AUC 0.7977
# JKNetMax Epoch 2000, Loss 0.2287, Val AUC 0.7924, Test AUC 0.7956
# JKNetMax Epoch 2100, Loss 0.2267, Val AUC 0.7928, Test AUC 0.7961
# JKNetMax Epoch 2200, Loss 0.2277, Val AUC 0.7924, Test AUC 0.7946
# JKNetMax Epoch 2300, Loss 0.2207, Val AUC 0.7924, Test AUC 0.7955
# JKNetMax Epoch 2400, Loss 0.2257, Val AUC 0.7889, Test AUC 0.7933
# JKNetMax Epoch 2500, Loss 0.2183, Val AUC 0.7924, Test AUC 0.7935
# JKNetMax Epoch 2600, Loss 0.2213, Val AUC 0.7897, Test AUC 0.7915
# JKNetMax Epoch 2700, Loss 0.2118, Val AUC 0.7907, Test AUC 0.7913
# JKNetMax Epoch 2800, Loss 0.2116, Val AUC 0.7940, Test AUC 0.7925
# JKNetMax Epoch 2900, Loss 0.2093, Val AUC 0.7895, Test AUC 0.7884
# JKNetMax Epoch 3000, Loss 0.2018, Val AUC 0.7864, Test AUC 0.7885
# JKNetMax Epoch 3100, Loss 0.2050, Val AUC 0.7893, Test AUC 0.7879
# JKNetMax Epoch 3200, Loss 0.2039, Val AUC 0.7898, Test AUC 0.7878
# JKNetMax Epoch 3300, Loss 0.2146, Val AUC 0.7888, Test AUC 0.7877
# JKNetMax Epoch 3400, Loss 0.2060, Val AUC 0.7884, Test AUC 0.7882
# JKNetMax Epoch 3500, Loss 0.2056, Val AUC 0.7855, Test AUC 0.7875
# JKNetMax Epoch 3600, Loss 0.2045, Val AUC 0.7897, Test AUC 0.7877
# JKNetMax Epoch 3700, Loss 0.1957, Val AUC 0.7847, Test AUC 0.7851
# JKNetMax Epoch 3800, Loss 0.1971, Val AUC 0.7896, Test AUC 0.7862
# JKNetMax Epoch 3900, Loss 0.2024, Val AUC 0.7856, Test AUC 0.7883
# JKNetMax Epoch 4000, Loss 0.2001, Val AUC 0.7869, Test AUC 0.7863
# JKNetMax Epoch 4100, Loss 0.1987, Val AUC 0.7875, Test AUC 0.7861
# JKNetMax Epoch 4200, Loss 0.1994, Val AUC 0.7881, Test AUC 0.7863
# JKNetMax Epoch 4300, Loss 0.1955, Val AUC 0.7838, Test AUC 0.7856
# JKNetMax Epoch 4400, Loss 0.2002, Val AUC 0.7864, Test AUC 0.7847
# JKNetMax Epoch 4500, Loss 0.1938, Val AUC 0.7869, Test AUC 0.7857
# JKNetMax Epoch 4600, Loss 0.1946, Val AUC 0.7855, Test AUC 0.7859
# JKNetMax Epoch 4700, Loss 0.1960, Val AUC 0.7862, Test AUC 0.7840
# JKNetMax Epoch 4800, Loss 0.1960, Val AUC 0.7858, Test AUC 0.7864
# JKNetMax Epoch 4900, Loss 0.1907, Val AUC 0.7856, Test AUC 0.7837
# JKNetMax Epoch 5000, Loss 0.1902, Val AUC 0.7856, Test AUC 0.7853
# JKNetMax Epoch 5100, Loss 0.1903, Val AUC 0.7848, Test AUC 0.7857
# JKNetMax Epoch 5200, Loss 0.1913, Val AUC 0.7841, Test AUC 0.7831
# JKNetMax Epoch 5300, Loss 0.1914, Val AUC 0.7882, Test AUC 0.7840
# JKNetMax Epoch 5400, Loss 0.1921, Val AUC 0.7848, Test AUC 0.7823
# JKNetMax Epoch 5500, Loss 0.1917, Val AUC 0.7836, Test AUC 0.7817
# JKNetMax Epoch 5600, Loss 0.1913, Val AUC 0.7845, Test AUC 0.7804
# JKNetMax Epoch 5700, Loss 0.1946, Val AUC 0.7854, Test AUC 0.7844
# JKNetMax Epoch 5800, Loss 0.1921, Val AUC 0.7838, Test AUC 0.7818
# JKNetMax Epoch 5900, Loss 0.1910, Val AUC 0.7837, Test AUC 0.7865
# JKNetMax Epoch 6000, Loss 0.1918, Val AUC 0.7823, Test AUC 0.7806
# JKNetMax Epoch 6100, Loss 0.1913, Val AUC 0.7842, Test AUC 0.7805
# JKNetMax Epoch 6200, Loss 0.1889, Val AUC 0.7835, Test AUC 0.7827
# JKNetMax Epoch 6300, Loss 0.1895, Val AUC 0.7845, Test AUC 0.7834
# JKNetMax Epoch 6400, Loss 0.1945, Val AUC 0.7794, Test AUC 0.7794
# JKNetMax Epoch 6500, Loss 0.1923, Val AUC 0.7839, Test AUC 0.7815
# JKNetMax Epoch 6600, Loss 0.1952, Val AUC 0.7853, Test AUC 0.7822
# JKNetMax Epoch 6700, Loss 0.1888, Val AUC 0.7834, Test AUC 0.7813
# JKNetMax Epoch 6800, Loss 0.1876, Val AUC 0.7842, Test AUC 0.7843
# JKNetMax Epoch 6900, Loss 0.1908, Val AUC 0.7851, Test AUC 0.7820
# JKNetMax Epoch 7000, Loss 0.1899, Val AUC 0.7828, Test AUC 0.7839
# JKNetMax Epoch 7100, Loss 0.1866, Val AUC 0.7837, Test AUC 0.7814
# JKNetMax Epoch 7200, Loss 0.1869, Val AUC 0.7828, Test AUC 0.7813
# JKNetMax Epoch 7300, Loss 0.1836, Val AUC 0.7824, Test AUC 0.7848
# JKNetMax Epoch 7400, Loss 0.1909, Val AUC 0.7837, Test AUC 0.7813
# JKNetMax Epoch 7500, Loss 0.1884, Val AUC 0.7826, Test AUC 0.7821
# JKNetMax Epoch 7600, Loss 0.1856, Val AUC 0.7860, Test AUC 0.7812
# JKNetMax Epoch 7700, Loss 0.1906, Val AUC 0.7839, Test AUC 0.7836
# JKNetMax Epoch 7800, Loss 0.1846, Val AUC 0.7829, Test AUC 0.7811
# JKNetMax Epoch 7900, Loss 0.1844, Val AUC 0.7840, Test AUC 0.7825
# JKNetMax Epoch 8000, Loss 0.1901, Val AUC 0.7813, Test AUC 0.7806
# JKNetMax Epoch 8100, Loss 0.1959, Val AUC 0.7838, Test AUC 0.7832
# JKNetMax Epoch 8200, Loss 0.1879, Val AUC 0.7807, Test AUC 0.7815
# JKNetMax Epoch 8300, Loss 0.1937, Val AUC 0.7836, Test AUC 0.7827
# JKNetMax Epoch 8400, Loss 0.1868, Val AUC 0.7843, Test AUC 0.7861
# JKNetMax Epoch 8500, Loss 0.1854, Val AUC 0.7823, Test AUC 0.7843
# JKNetMax Epoch 8600, Loss 0.1893, Val AUC 0.7816, Test AUC 0.7815
# JKNetMax Epoch 8700, Loss 0.1870, Val AUC 0.7833, Test AUC 0.7819
# JKNetMax Epoch 8800, Loss 0.1911, Val AUC 0.7855, Test AUC 0.7830
# JKNetMax Epoch 8900, Loss 0.1847, Val AUC 0.7816, Test AUC 0.7814
# JKNetMax Epoch 9000, Loss 0.1932, Val AUC 0.7852, Test AUC 0.7822
# JKNetMax Epoch 9100, Loss 0.1839, Val AUC 0.7823, Test AUC 0.7806
# JKNetMax Epoch 9200, Loss 0.1877, Val AUC 0.7772, Test AUC 0.7797
# JKNetMax Epoch 9300, Loss 0.1847, Val AUC 0.7804, Test AUC 0.7825
# JKNetMax Epoch 9400, Loss 0.1878, Val AUC 0.7766, Test AUC 0.7822
# JKNetMax Epoch 9500, Loss 0.1891, Val AUC 0.7823, Test AUC 0.7833
# JKNetMax Epoch 9600, Loss 0.1905, Val AUC 0.7782, Test AUC 0.7808
# JKNetMax Epoch 9700, Loss 0.1885, Val AUC 0.7822, Test AUC 0.7840
# JKNetMax Epoch 9800, Loss 0.1815, Val AUC 0.7806, Test AUC 0.7818
# JKNetMax Epoch 9900, Loss 0.1807, Val AUC 0.7813, Test AUC 0.7819
# JKNetMax Seed 123 → Best Val AUC 0.8104, Test @BestVal = 0.7996
# ===== MixHop =====
# MixHop Epoch 100, Loss 0.6086, Val AUC 0.6522, Test AUC 0.6911
# MixHop Epoch 200, Loss 0.5138, Val AUC 0.6546, Test AUC 0.7114
# MixHop Epoch 300, Loss 0.4657, Val AUC 0.6535, Test AUC 0.7079
# MixHop Epoch 400, Loss 0.4406, Val AUC 0.6534, Test AUC 0.7023
# MixHop Epoch 500, Loss 0.4230, Val AUC 0.6509, Test AUC 0.6996
# MixHop Epoch 600, Loss 0.4081, Val AUC 0.6511, Test AUC 0.6975
# MixHop Epoch 700, Loss 0.3906, Val AUC 0.6516, Test AUC 0.6970
# MixHop Epoch 800, Loss 0.3763, Val AUC 0.6508, Test AUC 0.6965
# MixHop Epoch 900, Loss 0.3633, Val AUC 0.6488, Test AUC 0.6945
# MixHop Epoch 1000, Loss 0.3557, Val AUC 0.6485, Test AUC 0.6927
# MixHop Epoch 1100, Loss 0.3464, Val AUC 0.6475, Test AUC 0.6917
# MixHop Epoch 1200, Loss 0.3387, Val AUC 0.6448, Test AUC 0.6901
# MixHop Epoch 1300, Loss 0.3314, Val AUC 0.6433, Test AUC 0.6893
# MixHop Epoch 1400, Loss 0.3236, Val AUC 0.6423, Test AUC 0.6888
# MixHop Epoch 1500, Loss 0.3173, Val AUC 0.6411, Test AUC 0.6872
# MixHop Epoch 1600, Loss 0.3088, Val AUC 0.6411, Test AUC 0.6853
# MixHop Epoch 1700, Loss 0.3021, Val AUC 0.6403, Test AUC 0.6828
# MixHop Epoch 1800, Loss 0.2964, Val AUC 0.6395, Test AUC 0.6810
# MixHop Epoch 1900, Loss 0.2896, Val AUC 0.6407, Test AUC 0.6795
# MixHop Epoch 2000, Loss 0.2818, Val AUC 0.6407, Test AUC 0.6775
# MixHop Epoch 2100, Loss 0.2782, Val AUC 0.6405, Test AUC 0.6772
# MixHop Epoch 2200, Loss 0.2722, Val AUC 0.6411, Test AUC 0.6765
# MixHop Epoch 2300, Loss 0.2684, Val AUC 0.6420, Test AUC 0.6758
# MixHop Epoch 2400, Loss 0.2630, Val AUC 0.6410, Test AUC 0.6755
# MixHop Epoch 2500, Loss 0.2605, Val AUC 0.6415, Test AUC 0.6746
# MixHop Epoch 2600, Loss 0.2547, Val AUC 0.6401, Test AUC 0.6735
# MixHop Epoch 2700, Loss 0.2510, Val AUC 0.6394, Test AUC 0.6724
# MixHop Epoch 2800, Loss 0.2493, Val AUC 0.6399, Test AUC 0.6711
# MixHop Epoch 2900, Loss 0.2458, Val AUC 0.6390, Test AUC 0.6707
# MixHop Epoch 3000, Loss 0.2409, Val AUC 0.6384, Test AUC 0.6695
# MixHop Epoch 3100, Loss 0.2388, Val AUC 0.6380, Test AUC 0.6695
# MixHop Epoch 3200, Loss 0.2368, Val AUC 0.6374, Test AUC 0.6688
# MixHop Epoch 3300, Loss 0.2336, Val AUC 0.6368, Test AUC 0.6689
# MixHop Epoch 3400, Loss 0.2306, Val AUC 0.6363, Test AUC 0.6690
# MixHop Epoch 3500, Loss 0.2281, Val AUC 0.6373, Test AUC 0.6685
# MixHop Epoch 3600, Loss 0.2260, Val AUC 0.6373, Test AUC 0.6680
# MixHop Epoch 3700, Loss 0.2252, Val AUC 0.6362, Test AUC 0.6684
# MixHop Epoch 3800, Loss 0.2195, Val AUC 0.6351, Test AUC 0.6691
# MixHop Epoch 3900, Loss 0.2179, Val AUC 0.6352, Test AUC 0.6685
# MixHop Epoch 4000, Loss 0.2175, Val AUC 0.6360, Test AUC 0.6687
# MixHop Epoch 4100, Loss 0.2169, Val AUC 0.6351, Test AUC 0.6676
# MixHop Epoch 4200, Loss 0.2125, Val AUC 0.6344, Test AUC 0.6670
# MixHop Epoch 4300, Loss 0.2124, Val AUC 0.6343, Test AUC 0.6679
# MixHop Epoch 4400, Loss 0.2112, Val AUC 0.6340, Test AUC 0.6665
# MixHop Epoch 4500, Loss 0.2101, Val AUC 0.6335, Test AUC 0.6674
# MixHop Epoch 4600, Loss 0.2086, Val AUC 0.6338, Test AUC 0.6668
# MixHop Epoch 4700, Loss 0.2051, Val AUC 0.6317, Test AUC 0.6665
# MixHop Epoch 4800, Loss 0.2068, Val AUC 0.6332, Test AUC 0.6664
# MixHop Epoch 4900, Loss 0.2060, Val AUC 0.6319, Test AUC 0.6658
# MixHop Epoch 5000, Loss 0.2032, Val AUC 0.6329, Test AUC 0.6658
# MixHop Epoch 5100, Loss 0.2034, Val AUC 0.6328, Test AUC 0.6656
# MixHop Epoch 5200, Loss 0.2020, Val AUC 0.6326, Test AUC 0.6655
# MixHop Epoch 5300, Loss 0.2035, Val AUC 0.6327, Test AUC 0.6645
# MixHop Epoch 5400, Loss 0.2027, Val AUC 0.6318, Test AUC 0.6658
# MixHop Epoch 5500, Loss 0.2007, Val AUC 0.6327, Test AUC 0.6656
# MixHop Epoch 5600, Loss 0.2015, Val AUC 0.6318, Test AUC 0.6657
# MixHop Epoch 5700, Loss 0.2024, Val AUC 0.6325, Test AUC 0.6647
# MixHop Epoch 5800, Loss 0.2000, Val AUC 0.6322, Test AUC 0.6649
# MixHop Epoch 5900, Loss 0.2015, Val AUC 0.6316, Test AUC 0.6653
# MixHop Epoch 6000, Loss 0.1986, Val AUC 0.6336, Test AUC 0.6645
# MixHop Epoch 6100, Loss 0.1991, Val AUC 0.6327, Test AUC 0.6633
# MixHop Epoch 6200, Loss 0.1975, Val AUC 0.6318, Test AUC 0.6650
# MixHop Epoch 6300, Loss 0.1984, Val AUC 0.6318, Test AUC 0.6650
# MixHop Epoch 6400, Loss 0.1983, Val AUC 0.6327, Test AUC 0.6634
# MixHop Epoch 6500, Loss 0.1971, Val AUC 0.6325, Test AUC 0.6639
# MixHop Epoch 6600, Loss 0.1975, Val AUC 0.6325, Test AUC 0.6645
# MixHop Epoch 6700, Loss 0.1968, Val AUC 0.6325, Test AUC 0.6639
# MixHop Epoch 6800, Loss 0.1984, Val AUC 0.6328, Test AUC 0.6645
# MixHop Epoch 6900, Loss 0.1980, Val AUC 0.6326, Test AUC 0.6637
# MixHop Epoch 7000, Loss 0.1982, Val AUC 0.6324, Test AUC 0.6647
# MixHop Epoch 7100, Loss 0.1982, Val AUC 0.6328, Test AUC 0.6648
# MixHop Epoch 7200, Loss 0.1987, Val AUC 0.6328, Test AUC 0.6642
# MixHop Epoch 7300, Loss 0.1956, Val AUC 0.6329, Test AUC 0.6650
# MixHop Epoch 7400, Loss 0.1961, Val AUC 0.6320, Test AUC 0.6640
# MixHop Epoch 7500, Loss 0.1957, Val AUC 0.6327, Test AUC 0.6644
# MixHop Epoch 7600, Loss 0.1986, Val AUC 0.6331, Test AUC 0.6648
# MixHop Epoch 7700, Loss 0.1968, Val AUC 0.6336, Test AUC 0.6648
# MixHop Epoch 7800, Loss 0.1979, Val AUC 0.6325, Test AUC 0.6653
# MixHop Epoch 7900, Loss 0.1962, Val AUC 0.6325, Test AUC 0.6643
# MixHop Epoch 8000, Loss 0.1955, Val AUC 0.6323, Test AUC 0.6637
# MixHop Epoch 8100, Loss 0.1972, Val AUC 0.6318, Test AUC 0.6644
# MixHop Epoch 8200, Loss 0.1965, Val AUC 0.6317, Test AUC 0.6650
# MixHop Epoch 8300, Loss 0.1984, Val AUC 0.6329, Test AUC 0.6645
# MixHop Epoch 8400, Loss 0.1963, Val AUC 0.6327, Test AUC 0.6640
# MixHop Epoch 8500, Loss 0.1951, Val AUC 0.6322, Test AUC 0.6646
# MixHop Epoch 8600, Loss 0.1966, Val AUC 0.6325, Test AUC 0.6639
# MixHop Epoch 8700, Loss 0.1971, Val AUC 0.6324, Test AUC 0.6644
# MixHop Epoch 8800, Loss 0.1966, Val AUC 0.6324, Test AUC 0.6644
# MixHop Epoch 8900, Loss 0.1964, Val AUC 0.6329, Test AUC 0.6645
# MixHop Epoch 9000, Loss 0.1963, Val AUC 0.6327, Test AUC 0.6644
# MixHop Epoch 9100, Loss 0.1982, Val AUC 0.6331, Test AUC 0.6643
# MixHop Epoch 9200, Loss 0.1980, Val AUC 0.6322, Test AUC 0.6643
# MixHop Epoch 9300, Loss 0.1970, Val AUC 0.6333, Test AUC 0.6649
# MixHop Epoch 9400, Loss 0.1973, Val AUC 0.6321, Test AUC 0.6644
# MixHop Epoch 9500, Loss 0.1963, Val AUC 0.6329, Test AUC 0.6647
# MixHop Epoch 9600, Loss 0.1974, Val AUC 0.6314, Test AUC 0.6641
# MixHop Epoch 9700, Loss 0.1975, Val AUC 0.6321, Test AUC 0.6649
# MixHop Epoch 9800, Loss 0.1989, Val AUC 0.6333, Test AUC 0.6641
# MixHop Epoch 9900, Loss 0.1956, Val AUC 0.6335, Test AUC 0.6650
# MixHop Seed 123 → Best Val AUC 0.6552, Test @BestVal = 0.7116
# ===== alternating MixHop JKNet =====
# AlternatingGCNMixHopJKNet Epoch 100, Loss 0.6069, Val AUC 0.7114, Test AUC 0.6910
# AlternatingGCNMixHopJKNet Epoch 200, Loss 0.5572, Val AUC 0.7012, Test AUC 0.6934
# AlternatingGCNMixHopJKNet Epoch 300, Loss 0.5394, Val AUC 0.6973, Test AUC 0.6956
# AlternatingGCNMixHopJKNet Epoch 400, Loss 0.5186, Val AUC 0.6968, Test AUC 0.6981
# AlternatingGCNMixHopJKNet Epoch 500, Loss 0.4644, Val AUC 0.7315, Test AUC 0.7186
# AlternatingGCNMixHopJKNet Epoch 600, Loss 0.3740, Val AUC 0.7860, Test AUC 0.8076
# AlternatingGCNMixHopJKNet Epoch 700, Loss 0.3370, Val AUC 0.7930, Test AUC 0.8267
# AlternatingGCNMixHopJKNet Epoch 800, Loss 0.3016, Val AUC 0.8032, Test AUC 0.8362
# AlternatingGCNMixHopJKNet Epoch 900, Loss 0.2755, Val AUC 0.8004, Test AUC 0.8355
# AlternatingGCNMixHopJKNet Epoch 1000, Loss 0.2676, Val AUC 0.7982, Test AUC 0.8341
# AlternatingGCNMixHopJKNet Epoch 1100, Loss 0.2568, Val AUC 0.7997, Test AUC 0.8340
# AlternatingGCNMixHopJKNet Epoch 1200, Loss 0.2381, Val AUC 0.8003, Test AUC 0.8319
# AlternatingGCNMixHopJKNet Epoch 1300, Loss 0.2325, Val AUC 0.7986, Test AUC 0.8306
# AlternatingGCNMixHopJKNet Epoch 1400, Loss 0.2239, Val AUC 0.7978, Test AUC 0.8294
# AlternatingGCNMixHopJKNet Epoch 1500, Loss 0.2125, Val AUC 0.7962, Test AUC 0.8280
# AlternatingGCNMixHopJKNet Epoch 1600, Loss 0.2141, Val AUC 0.7954, Test AUC 0.8275
# AlternatingGCNMixHopJKNet Epoch 1700, Loss 0.2068, Val AUC 0.7956, Test AUC 0.8272
# AlternatingGCNMixHopJKNet Epoch 1800, Loss 0.2042, Val AUC 0.7963, Test AUC 0.8268
# AlternatingGCNMixHopJKNet Epoch 1900, Loss 0.2002, Val AUC 0.7961, Test AUC 0.8266
# AlternatingGCNMixHopJKNet Epoch 2000, Loss 0.1972, Val AUC 0.7927, Test AUC 0.8257
# AlternatingGCNMixHopJKNet Epoch 2100, Loss 0.1903, Val AUC 0.7922, Test AUC 0.8260
# AlternatingGCNMixHopJKNet Epoch 2200, Loss 0.1919, Val AUC 0.7912, Test AUC 0.8221
# AlternatingGCNMixHopJKNet Epoch 2300, Loss 0.1825, Val AUC 0.7886, Test AUC 0.8216
# AlternatingGCNMixHopJKNet Epoch 2400, Loss 0.1899, Val AUC 0.7855, Test AUC 0.8212
# AlternatingGCNMixHopJKNet Epoch 2500, Loss 0.1857, Val AUC 0.7847, Test AUC 0.8202
# AlternatingGCNMixHopJKNet Epoch 2600, Loss 0.1834, Val AUC 0.7871, Test AUC 0.8210
# AlternatingGCNMixHopJKNet Epoch 2700, Loss 0.1755, Val AUC 0.7869, Test AUC 0.8202
# AlternatingGCNMixHopJKNet Epoch 2800, Loss 0.1740, Val AUC 0.7863, Test AUC 0.8198
# AlternatingGCNMixHopJKNet Epoch 2900, Loss 0.1742, Val AUC 0.7882, Test AUC 0.8198
# AlternatingGCNMixHopJKNet Epoch 3000, Loss 0.1707, Val AUC 0.7862, Test AUC 0.8188
# AlternatingGCNMixHopJKNet Epoch 3100, Loss 0.1705, Val AUC 0.7845, Test AUC 0.8185
# AlternatingGCNMixHopJKNet Epoch 3200, Loss 0.1778, Val AUC 0.7843, Test AUC 0.8169
# AlternatingGCNMixHopJKNet Epoch 3300, Loss 0.1714, Val AUC 0.7812, Test AUC 0.8176
# AlternatingGCNMixHopJKNet Epoch 3400, Loss 0.1682, Val AUC 0.7841, Test AUC 0.8179
# AlternatingGCNMixHopJKNet Epoch 3500, Loss 0.1611, Val AUC 0.7822, Test AUC 0.8189
# AlternatingGCNMixHopJKNet Epoch 3600, Loss 0.1685, Val AUC 0.7815, Test AUC 0.8192
# AlternatingGCNMixHopJKNet Epoch 3700, Loss 0.1663, Val AUC 0.7848, Test AUC 0.8198
# AlternatingGCNMixHopJKNet Epoch 3800, Loss 0.1642, Val AUC 0.7840, Test AUC 0.8180
# AlternatingGCNMixHopJKNet Epoch 3900, Loss 0.1609, Val AUC 0.7818, Test AUC 0.8175
# AlternatingGCNMixHopJKNet Epoch 4000, Loss 0.1635, Val AUC 0.7816, Test AUC 0.8178
# AlternatingGCNMixHopJKNet Epoch 4100, Loss 0.1603, Val AUC 0.7827, Test AUC 0.8193
# AlternatingGCNMixHopJKNet Epoch 4200, Loss 0.1593, Val AUC 0.7811, Test AUC 0.8185
# AlternatingGCNMixHopJKNet Epoch 4300, Loss 0.1545, Val AUC 0.7789, Test AUC 0.8192
# AlternatingGCNMixHopJKNet Epoch 4400, Loss 0.1545, Val AUC 0.7798, Test AUC 0.8198
# AlternatingGCNMixHopJKNet Epoch 4500, Loss 0.1566, Val AUC 0.7802, Test AUC 0.8178
# AlternatingGCNMixHopJKNet Epoch 4600, Loss 0.1545, Val AUC 0.7784, Test AUC 0.8167
# AlternatingGCNMixHopJKNet Epoch 4700, Loss 0.1488, Val AUC 0.7793, Test AUC 0.8192
# AlternatingGCNMixHopJKNet Epoch 4800, Loss 0.1570, Val AUC 0.7766, Test AUC 0.8163
# AlternatingGCNMixHopJKNet Epoch 4900, Loss 0.1571, Val AUC 0.7771, Test AUC 0.8161
# AlternatingGCNMixHopJKNet Epoch 5000, Loss 0.1576, Val AUC 0.7756, Test AUC 0.8195
# AlternatingGCNMixHopJKNet Epoch 5100, Loss 0.1471, Val AUC 0.7753, Test AUC 0.8170
# AlternatingGCNMixHopJKNet Epoch 5200, Loss 0.1534, Val AUC 0.7754, Test AUC 0.8169
# AlternatingGCNMixHopJKNet Epoch 5300, Loss 0.1514, Val AUC 0.7778, Test AUC 0.8168
# AlternatingGCNMixHopJKNet Epoch 5400, Loss 0.1566, Val AUC 0.7744, Test AUC 0.8166
# AlternatingGCNMixHopJKNet Epoch 5500, Loss 0.1603, Val AUC 0.7773, Test AUC 0.8180
# AlternatingGCNMixHopJKNet Epoch 5600, Loss 0.1557, Val AUC 0.7765, Test AUC 0.8169
# AlternatingGCNMixHopJKNet Epoch 5700, Loss 0.1577, Val AUC 0.7768, Test AUC 0.8173
# AlternatingGCNMixHopJKNet Epoch 5800, Loss 0.1524, Val AUC 0.7751, Test AUC 0.8175
# AlternatingGCNMixHopJKNet Epoch 5900, Loss 0.1486, Val AUC 0.7748, Test AUC 0.8159
# AlternatingGCNMixHopJKNet Epoch 6000, Loss 0.1510, Val AUC 0.7771, Test AUC 0.8192
# AlternatingGCNMixHopJKNet Epoch 6100, Loss 0.1505, Val AUC 0.7773, Test AUC 0.8166
# AlternatingGCNMixHopJKNet Epoch 6200, Loss 0.1469, Val AUC 0.7727, Test AUC 0.8145
# AlternatingGCNMixHopJKNet Epoch 6300, Loss 0.1451, Val AUC 0.7719, Test AUC 0.8151
# AlternatingGCNMixHopJKNet Epoch 6400, Loss 0.1469, Val AUC 0.7751, Test AUC 0.8167
# AlternatingGCNMixHopJKNet Epoch 6500, Loss 0.1483, Val AUC 0.7736, Test AUC 0.8172
# AlternatingGCNMixHopJKNet Epoch 6600, Loss 0.1448, Val AUC 0.7731, Test AUC 0.8167
# AlternatingGCNMixHopJKNet Epoch 6700, Loss 0.1509, Val AUC 0.7720, Test AUC 0.8172
# AlternatingGCNMixHopJKNet Epoch 6800, Loss 0.1422, Val AUC 0.7731, Test AUC 0.8181
# AlternatingGCNMixHopJKNet Epoch 6900, Loss 0.1426, Val AUC 0.7724, Test AUC 0.8178
# AlternatingGCNMixHopJKNet Epoch 7000, Loss 0.1434, Val AUC 0.7735, Test AUC 0.8168
# AlternatingGCNMixHopJKNet Epoch 7100, Loss 0.1518, Val AUC 0.7737, Test AUC 0.8148
# AlternatingGCNMixHopJKNet Epoch 7200, Loss 0.1435, Val AUC 0.7725, Test AUC 0.8172
# AlternatingGCNMixHopJKNet Epoch 7300, Loss 0.1515, Val AUC 0.7731, Test AUC 0.8170
# AlternatingGCNMixHopJKNet Epoch 7400, Loss 0.1430, Val AUC 0.7759, Test AUC 0.8176
# AlternatingGCNMixHopJKNet Epoch 7500, Loss 0.1522, Val AUC 0.7735, Test AUC 0.8184
# AlternatingGCNMixHopJKNet Epoch 7600, Loss 0.1425, Val AUC 0.7730, Test AUC 0.8156
# AlternatingGCNMixHopJKNet Epoch 7700, Loss 0.1384, Val AUC 0.7726, Test AUC 0.8162
# AlternatingGCNMixHopJKNet Epoch 7800, Loss 0.1495, Val AUC 0.7719, Test AUC 0.8173
# AlternatingGCNMixHopJKNet Epoch 7900, Loss 0.1498, Val AUC 0.7720, Test AUC 0.8166
# AlternatingGCNMixHopJKNet Epoch 8000, Loss 0.1416, Val AUC 0.7745, Test AUC 0.8174
# AlternatingGCNMixHopJKNet Epoch 8100, Loss 0.1466, Val AUC 0.7729, Test AUC 0.8163
# AlternatingGCNMixHopJKNet Epoch 8200, Loss 0.1405, Val AUC 0.7740, Test AUC 0.8158
# AlternatingGCNMixHopJKNet Epoch 8300, Loss 0.1382, Val AUC 0.7708, Test AUC 0.8161
# AlternatingGCNMixHopJKNet Epoch 8400, Loss 0.1493, Val AUC 0.7701, Test AUC 0.8164
# AlternatingGCNMixHopJKNet Epoch 8500, Loss 0.1467, Val AUC 0.7737, Test AUC 0.8162
# AlternatingGCNMixHopJKNet Epoch 8600, Loss 0.1439, Val AUC 0.7713, Test AUC 0.8164
# AlternatingGCNMixHopJKNet Epoch 8700, Loss 0.1416, Val AUC 0.7726, Test AUC 0.8178
# AlternatingGCNMixHopJKNet Epoch 8800, Loss 0.1446, Val AUC 0.7704, Test AUC 0.8152
# AlternatingGCNMixHopJKNet Epoch 8900, Loss 0.1370, Val AUC 0.7711, Test AUC 0.8162
# AlternatingGCNMixHopJKNet Epoch 9000, Loss 0.1436, Val AUC 0.7721, Test AUC 0.8146
# AlternatingGCNMixHopJKNet Epoch 9100, Loss 0.1396, Val AUC 0.7722, Test AUC 0.8151
# AlternatingGCNMixHopJKNet Epoch 9200, Loss 0.1434, Val AUC 0.7694, Test AUC 0.8147
# AlternatingGCNMixHopJKNet Epoch 9300, Loss 0.1422, Val AUC 0.7689, Test AUC 0.8141
# AlternatingGCNMixHopJKNet Epoch 9400, Loss 0.1409, Val AUC 0.7732, Test AUC 0.8170
# AlternatingGCNMixHopJKNet Epoch 9500, Loss 0.1357, Val AUC 0.7703, Test AUC 0.8168
# AlternatingGCNMixHopJKNet Epoch 9600, Loss 0.1397, Val AUC 0.7717, Test AUC 0.8150
# AlternatingGCNMixHopJKNet Epoch 9700, Loss 0.1401, Val AUC 0.7723, Test AUC 0.8145
# AlternatingGCNMixHopJKNet Epoch 9800, Loss 0.1395, Val AUC 0.7714, Test AUC 0.8138
# AlternatingGCNMixHopJKNet Epoch 9900, Loss 0.1427, Val AUC 0.7723, Test AUC 0.8148
# AlternatingGCNMixHopJKNet Seed 123 → Best Val AUC 0.8052, Test @BestVal = 0.8357
# GCN Mean Test AUC = 0.7944 ± 0.0000
# JKNetMax Mean Test AUC = 0.7996 ± 0.0000
# MixHop Mean Test AUC = 0.7116 ± 0.0000
# AlternatingMixHopJKNet Mean Test AUC = 0.8357 ± 0.0000
